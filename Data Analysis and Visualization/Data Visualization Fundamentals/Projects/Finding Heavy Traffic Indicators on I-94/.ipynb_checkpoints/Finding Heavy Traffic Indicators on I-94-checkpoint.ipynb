# %% [markdown]
# # Finding Heavy Traffic Indicators on I-94

# %% [markdown]
# # 1. The I-94 Traffic Dataset

# %% [markdown]
# In this project we will be analyzing a dataset regrading westbound traffic on the I-94 Interstate Highway.
#
# We will be determining different heavy traffic indicators on I-94 such as weather, time, and day.

# %%
import pandas as pd
traffic=pd.read_csv("Metro_Interstate_Traffic_Volume.csv")

print(traffic.head())
print(traffic.tail())
print(traffic.info())
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 48199    None  283.45      0.0      0.0          75        Clouds
# 48200    None  282.76      0.0      0.0          90        Clouds
# ...

# %% [markdown]
# # 2. Analyzing Traffic Volume

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

traffic["traffic_volume"].plot.hist()
plt.show()


print(traffic["traffic_volume"].describe())
# Out:
# count    48204.000000
# mean      3259.818355
# std       1986.860670
# min          0.000000
# 25%       1193.000000
# 50%       3380.000000
# 75%       4933.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64

# %% [markdown]
# Above we can see that the hourly traffic varied between 0 and 7280. We can also see that we have a bimodal graph. It is likely that this varied based on time of day, with the bottom 25% occurring during the night and the upper 25%-40% occuring during rush hour.

# %% [markdown]
# # 3. Traffic Volume: Day vs. Night

# %%
traffic["date_time"]=pd.to_datetime(traffic["date_time"])
day=traffic[(traffic["date_time"].dt.hour>=7) & (traffic["date_time"].dt.hour<19)]
night=traffic[(traffic["date_time"].dt.hour>=19) | (traffic["date_time"].dt.hour <7)]

print(night.shape)
# Out:
# (24327, 9)

# %% [markdown]
# # 4. Traffic Volume: Day vs. Night (II)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.hist(day["traffic_volume"])
plt.title("Day Traffic")
plt.xlabel("Cars on road")
plt.ylabel("Frequency")
plt.xlim((0,7500))
plt.ylim((0,8000))
plt.subplot(1,2,2)
plt.hist(night["traffic_volume"])
plt.title("Night Traffic")
plt.xlabel("Cars on road")
plt.ylabel("Frequency")
plt.xlim((0,7500))
plt.ylim((0,8000))


plt.show()

print(day["traffic_volume"].describe())
print(night["traffic_volume"].describe())
# Out:
# count    23877.000000
# mean      4762.047452
# std       1174.546482
# min          0.000000
# 25%       4252.000000
# 50%       4820.000000
# 75%       5559.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64
# count    24327.000000
# mean      1785.377441
# std       1441.951197
# min          0.000000
# 25%        530.000000
# 50%       1287.000000
# 75%       2819.000000
# max       6386.000000
# Name: traffic_volume, dtype: float64

# %% [markdown]
# We can see above that our day traffic is far greater. The day traffic is almost always between 4000 and 6000. While the night traffic is generally between 0 and 3000. The Day traffic is greatly skewed to the right while the night traffic is skewed to the left.
#
# Since we are focused on heavy traffic indicators and heavy traffic during the night is quite rare, we will only focus on the daytime data going forward.

# %% [markdown]
# # 5. Time Indicators

# %%
day['month'] = day['date_time'].dt.month
by_month = day.groupby('month').mean()
by_month['traffic_volume']

by_month['traffic_volume'].plot.line()
plt.show()

print(by_month)
# Out:
# <ipython-input-5-66865d44fdb4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day['month'] = day['date_time'].dt.month
#              temp   rain_1h   snow_1h  clouds_all  traffic_volume
# month
# 1      265.483409  0.015080  0.000631   58.554108     4495.613727
# 2      266.663789  0.004019  0.000000   51.550459     4711.198394
# 3      273.619940  0.015839  0.000000   56.827811     4889.409560
# 4      279.661071  0.105343  0.000000   59.221525     4906.894305
# 5      289.282668  0.130863  0.000000   56.548825     4911.121609
# 6      294.576068  0.271121  0.000000   48.612374     4898.019566
# 7      296.785052  4.412258  0.000000   42.176619     4595.035744
# 8      295.119191  0.228113  0.000000   42.556892     4928.302035
# ...

# %% [markdown]
# We can see above that traffic fallls during the Winter months, and generally stays high from March to October except for July. We can see in our data that rain in July is particularly high. However, the fact that it is so much higher suggests that this is likely an error in our data. If it rained nearly 20 times more in July than it did in any other month, there would likely be more evidence to this.

# %%
day["year"]=day["date_time"].dt.year
day["day"]=day["date_time"].dt.day
day["hour"]=day["date_time"].dt.hour
july=day[day["month"]==7]
july=july.groupby("year").mean()
july["traffic_volume"].plot.line()
plt.show()

print(july)
# Out:
# <ipython-input-6-a873d5556059>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day["year"]=day["date_time"].dt.year
# <ipython-input-6-a873d5556059>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day["day"]=day["date_time"].dt.day
# <ipython-input-6-a873d5556059>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# Above we can see that traffic in July was lowered by an outlier in 2016. We can also see that the increased rain in July is also caused by 2016.

# %%
july_2016=day[(day["month"]==7) & (day["year"]==2016)]

print(july_2016)

plt.plot(july_2016["day"],july_2016["rain_1h"])

july_11=july_2016[july_2016["day"]==11]
plt.show()

plt.plot(july_11["hour"],july_11["rain_1h"])
plt.show()

print(july_11)

print(july_11[july_11["hour"]==17])
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 24589    None  284.59      0.0      0.0          20       Clouds
# 24590    None  286.51      0.0      0.0          20       Clouds
# 24591    None  288.14      0.0      0.0          40       Clouds
# 24592    None  289.45      0.0      0.0          40       Clouds
# 24593    None  290.87      0.0      0.0          20       Clouds
# ...       ...     ...      ...      ...         ...          ...
# 25388    None  300.17      0.0      0.0          75       Clouds
# 25389    None  301.01      0.0      0.0          75       Clouds
# 25390    None  300.90      0.0      0.0          40       Clouds
# 25391    None  300.78      0.0      0.0          75       Clouds
# 25392    None  300.48      0.0      0.0          75       Clouds
#
#       weather_description           date_time  traffic_volume  month  year  \
# 24589          few clouds 2016-07-01 07:00:00            5217      7  2016
# ...

# %% [markdown]
# As we can see above, the increased rain in July can be traced back to a single hour in that year. On July 11th, 2016 at 5pm, our data says that we had an inordinate amount of rain. This must be a typo. However, since traffic was still flowing normally during this, we know that the lowered traffic in July was not due to rainfall.

# %%
july_2016=day[(day["month"]==7) & (day["year"]==2016)]

print(july_2016)

plt.plot(july_2016["day"],july_2016["traffic_volume"])
plt.xlabel("Days")
plt.ylabel("Traffic Volume")
plt.title("July 2016 Traffic")
plt.show()

july_2015=day[(day["month"]==7) & (day["year"]==2015)]

print(july_2015)

plt.plot(july_2015["day"],july_2015["traffic_volume"])
plt.xlabel("Days")
plt.ylabel("Traffic Volume")
plt.title("July 2015 Traffic")
plt.show()
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 24589    None  284.59      0.0      0.0          20       Clouds
# 24590    None  286.51      0.0      0.0          20       Clouds
# 24591    None  288.14      0.0      0.0          40       Clouds
# 24592    None  289.45      0.0      0.0          40       Clouds
# 24593    None  290.87      0.0      0.0          20       Clouds
# ...       ...     ...      ...      ...         ...          ...
# 25388    None  300.17      0.0      0.0          75       Clouds
# 25389    None  301.01      0.0      0.0          75       Clouds
# 25390    None  300.90      0.0      0.0          40       Clouds
# 25391    None  300.78      0.0      0.0          75       Clouds
# 25392    None  300.48      0.0      0.0          75       Clouds
#
#       weather_description           date_time  traffic_volume  month  year  \
# 24589          few clouds 2016-07-01 07:00:00            5217      7  2016
# ...

# %% [markdown]
# We can see that traffic in July 2016 fell during several periods, particularly during July 23/24 where it dropped to nearly 0 for some days. This may be caused by [consturction](https://www.crainsdetroit.com/article/20160728/NEWS/160729841/weekend-construction-i-96-us-23-bridge-work-i-94-lane-closures-i-696).

# %% [markdown]
# # 6. Time Indicators (II)

# %%
day["dayofweek"]=day["date_time"].dt.dayofweek
by_dayofweek=day.groupby("dayofweek").mean()

by_dayofweek["traffic_volume"]

print(by_dayofweek)

by_dayofweek["traffic_volume"].plot.line()
plt.xlabel("Day Of Week")
plt.ylabel("Traffic Volume")

plt.show()
# Out:
#                  temp   rain_1h   snow_1h  clouds_all  traffic_volume  \
# dayofweek
# 0          282.262755  2.923823  0.000017   57.508053     4893.551286
# 1          282.301770  0.129172  0.000194   52.333234     5189.004782
# 2          282.198316  0.068099  0.001091   53.662119     5284.454282
# 3          282.279115  0.172436  0.000148   53.993191     5311.303730
# 4          282.181216  0.092828  0.000225   51.412200     5291.600829
# 5          282.300646  0.107596  0.000094   50.446376     3927.249558
# 6          282.280340  0.133170  0.000000   52.288699     3436.541789
#
#               month         year        day       hour
# dayofweek
# 0          6.401243  2015.524442  15.301498  12.472732
# 1          6.458757  2015.582487  15.577107  12.369994
# 2          6.619158  2015.491147  15.989550  12.453411
# 3          6.501184  2015.484902  15.862049  12.459739
# 4          6.575067  2015.514954  15.956766  12.454545
# ...

# %% [markdown]
# We can see above that traffic during the day is significantly higher on workdays than on weekends.

# %% [markdown]
# # 7. Time Indicators (III)

# %%
bussiness_days=day[day["dayofweek"]<=4]
weekend=day[day["dayofweek"]>=5]

by_hour_bussiness=bussiness_days.groupby("hour").mean()
by_hour_weekend=weekend.groupby("hour").mean()

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
by_hour_bussiness["traffic_volume"].plot.line()
plt.xlabel("Hours")
plt.ylabel("Traffic Volume")
plt.title("Bussiness Day Traffic")
plt.ylim((1000,6500))
plt.subplot(1,2,2)
by_hour_weekend["traffic_volume"].plot.line()
plt.xlabel("Hours")
plt.ylabel("Traffic Volume")
plt.title("Weekend Traffic")
plt.ylim((1000,6500))
# Out:
# (1000.0, 6500.0)

# %% [markdown]
# We can see above that the business day traffic is bimodal, with peaks at 7am and 5pm. This is when people are going to and from work.
#
# On weekends, the traffic is different. It is slightly skewed left and flattens out from noon until 6PM.

# %% [markdown]
# # 8. Weather Indicators

# %%
day.corr()["traffic_volume"]
# Out:
# temp              0.128317
# rain_1h           0.003697
# snow_1h           0.001265
# clouds_all       -0.032932
# traffic_volume    1.000000
# month            -0.022337
# year             -0.003557
# day              -0.011063
# hour              0.172704
# dayofweek        -0.416453
# Name: traffic_volume, dtype: float64

# %% [markdown]
# Above we can see that there is some weak correlation between traffic volume and temperature. With there being essentially no correlation between traffic volume and any other weather column.

# %%
day["temp_f"]=(day["temp"]-273.15)*1.8+32
print(day["temp_f"])

plt.scatter(day["traffic_volume"],day["temp_f"])
plt.ylim((-30,110))
plt.ylabel("Temperature")
plt.xlabel("Traffic Volume")
plt.title("Traffic Volume vs Temperature")
# Out:
# 0        59.234
# 1        61.178
# 2        61.574
# 3        62.564
# 4        64.382
#           ...
# 48194    51.242
# 48195    51.242
# 48196    52.214
# 48197    52.952
# 48198    51.890
# Name: temp_f, Length: 23877, dtype: float64
# <ipython-input-22-2a6657620084>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day["temp_f"]=(day["temp"]-273.15)*1.8+32
# Text(0.5, 1.0, 'Traffic Volume vs Temperature')

# %% [markdown]
# Above we can see that temperature is not a good indicator of traffic
