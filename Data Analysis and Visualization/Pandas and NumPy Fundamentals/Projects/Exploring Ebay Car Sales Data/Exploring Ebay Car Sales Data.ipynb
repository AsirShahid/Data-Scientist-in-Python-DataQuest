# %% [markdown]
# # 1. Introduction

# %% [markdown]
# dateCrawled - When this ad was first crawled. All field-values are taken from this date.
#
# name - Name of the car.
#
# seller - Whether the seller is private or a dealer.
#
# offerType - The type of listing
#
# price - The price on the ad to sell the car.
#
# abtest - Whether the listing is included in an A/B test.
#
# vehicleType - The vehicle Type.
#
# yearOfRegistration - The year in which the car was first registered.
#
# gearbox - The transmission type.
#
# powerPS - The power of the car in PS.
#
# model - The car model name.
#
# kilometer - How many kilometers the car has driven.
#
# monthOfRegistration - The month in which the car was first registered.
#
# fuelType - What type of fuel the car uses.
#
# brand - The brand of the car.
#
# notRepairedDamage - If the car has a damage which is not yet repaired.
#
# dateCreated - The date on which the eBay listing was created.
#
# nrOfPictures - The number of pictures in the ad.
#
# postalCode - The postal code for the location of the vehicle.
#
# lastSeenOnline - When the crawler saw this ad last online.

# %%
import numpy as np
import pandas as pd

autos=pd.read_csv("autos.csv",encoding="Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %% [markdown]
# Above we can see some important information regarding our data. First of all, we have 5 differetn columns with a significant number of missing data, however most columns have all the data that we need.
#
# We can also see that some pieces of data, such as the price and odometer readings, are stored as objects, but would better be stored as ints or floats.

# %% [markdown]
# # 2. Cleaning Column Names

# %% [markdown]
# We can convert the column names from camelcase to snakecase.

# %%
print(autos.columns)

fixed_columns=['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

autos.columns=fixed_columns

print(autos.columns)
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
print(autos.head())
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# # 3. Initial Exploration and Cleaning

# %%
autos.describe()
# Out:
#        registration_year      power_ps  registration_month  nr_of_pictures  \
# count       50000.000000  50000.000000        50000.000000         50000.0
# mean         2005.073280    116.355920            5.723360             0.0
# std           105.712813    209.216627            3.711984             0.0
# min          1000.000000      0.000000            0.000000             0.0
# 25%          1999.000000     70.000000            3.000000             0.0
# 50%          2003.000000    105.000000            6.000000             0.0
# 75%          2008.000000    150.000000            9.000000             0.0
# max          9999.000000  17700.000000           12.000000             0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %%
autos.drop("nr_of_pictures",axis=1,inplace=True)

# %% [markdown]
# The `nr_of_pictures` column seems to be useless as every value in the column is 0. Thus, we should be able to safely remove this column from our data set.

# %%
autos["registration_year"].unique()
# Out:
# array([2004, 1997, 2009, 2007, 2003, 2006, 1995, 1998, 2000, 2017, 2010,
#        1999, 1982, 1990, 2015, 2014, 1996, 1992, 2005, 2002, 2012, 2011,
#        2008, 1985, 2016, 1994, 1986, 2001, 2018, 2013, 1972, 1993, 1988,
#        1989, 1967, 1973, 1956, 1976, 4500, 1987, 1991, 1983, 1960, 1969,
#        1950, 1978, 1980, 1984, 1963, 1977, 1961, 1968, 1934, 1965, 1971,
#        1966, 1979, 1981, 1970, 1974, 1910, 1975, 5000, 4100, 2019, 1959,
#        9996, 9999, 6200, 1964, 1958, 1800, 1948, 1931, 1943, 9000, 1941,
#        1962, 1927, 1937, 1929, 1000, 1957, 1952, 1111, 1955, 1939, 8888,
#        1954, 1938, 2800, 5911, 1500, 1953, 1951, 4800, 1001])

# %% [markdown]
# We can see that there are many registration years which are simply not reasonable. There are many registration years that are from far in the future and others that are frim far in the past before cars were invented. We can remove any rows with a registration year that is outside of a certain range.

# %%
autos=autos[(autos["registration_year"]<=2021) & (autos["registration_year"]>1900)]

# %%
autos["registration_year"].unique()
# Out:
# array([2004, 1997, 2009, 2007, 2003, 2006, 1995, 1998, 2000, 2017, 2010,
#        1999, 1982, 1990, 2015, 2014, 1996, 1992, 2005, 2002, 2012, 2011,
#        2008, 1985, 2016, 1994, 1986, 2001, 2018, 2013, 1972, 1993, 1988,
#        1989, 1967, 1973, 1956, 1976, 1987, 1991, 1983, 1960, 1969, 1950,
#        1978, 1980, 1984, 1963, 1977, 1961, 1968, 1934, 1965, 1971, 1966,
#        1979, 1981, 1970, 1974, 1910, 1975, 2019, 1959, 1964, 1958, 1948,
#        1931, 1943, 1941, 1962, 1927, 1937, 1929, 1957, 1952, 1955, 1939,
#        1954, 1938, 1953, 1951])

# %%
autos["registration_month"].unique()
autos["registration_month"].value_counts()
# Out:
# 3     5070
# 0     5060
# 6     4367
# 5     4107
# 4     4102
# 7     3947
# 10    3651
# 12    3446
# 9     3389
# 11    3359
# 1     3282
# 8     3191
# 2     3005
# Name: registration_month, dtype: int64

# %% [markdown]
# We can see that the most common registration month is "0". Since there is no 0th month, it is possible that 0 was put in as typo. Though the frequency of this likely suggests that 0 was placed for listings without a stated registration month.

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %%
autos["odometer"]=(autos["odometer"].str.replace("km","").str.replace(",","").astype(int))
# Out:
# <ipython-input-13-ab6506b47db3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autos["odometer"]=(autos["odometer"].str.replace("km","").str.replace(",","").astype(int))

# %%
print(autos["odometer"])
# Out:
# 0        150000
# 1        150000
# 2         70000
# 3         70000
# 4        150000
#           ...
# 49995    100000
# 49996    150000
# 49997      5000
# 49998     40000
# 49999    150000
# Name: odometer, Length: 49976, dtype: int64

# %%
autos.rename({"odometer":"odometer_km"},inplace=True,axis=1)
# Out:
# /usr/lib64/python3.9/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
print(autos.columns)
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer_km', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'postal_code', 'last_seen'],
#       dtype='object')

# %%
autos["price"]=(autos["price"].str.replace("$","").str.replace(",","").astype(int))
# Out:
# <ipython-input-17-8bf8d8941acc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autos["price"]=(autos["price"].str.replace("$","").str.replace(",","").astype(int))

# %%
print(autos["price"])
# Out:
# 0         5000
# 1         8500
# 2         8990
# 3         4350
# 4         1350
#          ...
# 49995    24900
# 49996     1980
# 49997    13200
# 49998    22900
# 49999     1250
# Name: price, Length: 48545, dtype: int64

# %% [markdown]
# # 4. Exploring the Odometer and Price Columns

# %%
autos.describe()
# Out:
#               price  registration_year      power_ps    odometer_km  \
# count  4.997600e+04       49976.000000  49976.000000   49976.000000
# mean   9.841923e+03        2003.366836    116.321634  125786.877701
# std    4.812198e+05           7.693943    208.979969   39970.469598
# min    0.000000e+00        1910.000000      0.000000    5000.000000
# 25%    1.100000e+03        1999.000000     70.000000  125000.000000
# 50%    2.950000e+03        2003.000000    105.000000  150000.000000
# 75%    7.200000e+03        2008.000000    150.000000  150000.000000
# max    1.000000e+08        2019.000000  17700.000000  150000.000000
#
#        registration_month   postal_code
# count        49976.000000  49976.000000
# mean             5.725068  50814.988014
# std              3.711228  25781.624480
# min              0.000000   1067.000000
# 25%              3.000000  30451.000000
# 50%              6.000000  49577.000000
# 75%              9.000000  71543.000000
# ...

# %%
print(autos["odometer_km"].unique())
# Out:
# [150000  70000  50000  80000  10000  30000 125000  90000  20000  60000
#    5000 100000  40000]

# %%
print(autos["price"].sort_values())
# Out:
# 6472            0
# 45170           0
# 16323           0
# 45180           0
# 11339           0
#            ...
# 39377    12345678
# 47598    12345678
# 27371    12345678
# 42221    27322222
# 39705    99999999
# Name: price, Length: 49976, dtype: int64

# %% [markdown]
# Above we can see that the prices we have listed are not accurate in some cases. It is likely that the listings for vehicles that are \\$0 as well as listings with exorbitant prices, such as the ones above \\$500,000, do not have accurate prices. We shall remove these rows from our dataset in order to get more accurate figures

# %%
print(autos.iloc[[18089,43923,15225,29499,8445]])
# Out:
#               date_crawled                                               name  \
# 18098  2016-03-29 13:59:47                       Opel_Vectra_1.8_Edition_2000
# 43944  2016-03-09 12:43:06                           Audi80_/_B3__Reserviert_
# 15234  2016-03-07 12:54:04  BMW_335i_xDrive_Aut._Luxury_Line_NP_ueber_70.0...
# 29515  2016-03-15 10:50:40                                         Opel_Corsa
# 8451   2016-03-23 12:51:43                           Ford_Fiesta_1.3_HU_11/17
#
#        seller offer_type  price  ab_test vehicle_type  registration_year  \
# 18098  privat    Angebot   1600  control    limousine               2000
# 43944  privat    Angebot    250  control          NaN               2016
# 15234  privat    Angebot  27900     test    limousine               2013
# 29515  privat    Angebot    200  control   kleinwagen               1999
# 8451   privat    Angebot    999  control   kleinwagen               1998
#
# ...

# %%
print(autos.iloc[[27371,47598,39377,42221,39705]])
# Out:
#               date_crawled                                               name  \
# 27385  2016-03-28 18:37:21              Fiat_Marea_1.6_16v_schoener_Innenraum
# 47619  2016-03-22 00:56:22                                 BMW_535i_V8_5_Gang
# 39397  2016-03-22 11:54:52     Opel_Tigra_Twin_Top_1.4_*Klima*_Cabrio*_Tuev_*
# 42242  2016-03-21 15:55:11                                  Bmw_e46_1_8_Liter
# 39725  2016-03-25 22:54:31  Dodge_1937_Hotrod_Flathead_Scheunenfund_Oldtim...
#
#        seller offer_type  price  ab_test vehicle_type  registration_year  \
# 27385  privat    Angebot    350  control    limousine               1997
# 47619  privat    Angebot   1900  control    limousine               1996
# 39397  privat    Angebot   3280  control       cabrio               2005
# 42242  privat    Angebot   2200  control    limousine               2000
# 39725  privat    Angebot   8990  control    limousine               1937
#
# ...

# %%
print((autos["price"]>10000))
autos=autos[(autos["price"]>0) & (autos["price"]<500000)]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995     True
# 49996    False
# 49997     True
# 49998     True
# 49999    False
# Name: price, Length: 48548, dtype: bool

# %%
autos.describe()
# Out:
#                price  registration_year      power_ps    odometer_km  \
# count   48545.000000       48545.000000  48545.000000   48545.000000
# mean     5888.431764        2003.461510    117.156123  125819.136883
# std      9059.345265           7.566196    200.385362   39723.379171
# min         1.000000        1910.000000      0.000000    5000.000000
# 25%      1200.000000        1999.000000     71.000000  125000.000000
# 50%      3000.000000        2004.000000    107.000000  150000.000000
# 75%      7490.000000        2008.000000    150.000000  150000.000000
# max    350000.000000        2019.000000  17700.000000  150000.000000
#
#        registration_month   postal_code
# count        48545.000000  48545.000000
# mean             5.783603  50975.125121
# std              3.684938  25748.944248
# min              0.000000   1067.000000
# 25%              3.000000  30657.000000
# 50%              6.000000  49716.000000
# 75%              9.000000  71665.000000
# ...
